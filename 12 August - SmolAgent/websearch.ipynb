# %%
#%pip install "smolagents[toolkit]"
# Out:
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.7 MB 4.9 MB/s eta 0:00:01
#    -------------------- ------------------- 2.4/4.7 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.4/4.7 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.5/4.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 5.4 MB/s  0:00:00
# ...
#
#    ---- ----------------------------------- 1/9 [primp]
#    -------- ------------------------------- 2/9 [hyperframe]
#    ------------- -------------------------- 3/9 [hpack]
#    ------------- -------------------------- 3/9 [hpack]
#    ----------------- ---------------------- 4/9 [fake-useragent]
#    -------------------------- ------------- 6/9 [h2]
#    -------------------------- ------------- 6/9 [h2]
#    ------------------------------- -------- 7/9 [ddgs]
#    ------------------------------- -------- 7/9 [ddgs]
# ...

# %%
import smolagents
print(smolagents.__version__)
# Out:
# 1.26.0

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
from huggingface_hub import login
login("huggingface_hub_token")  # Replace with your actual Hugging Face token

# %%
from huggingface_hub import login
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

# Run login() only once in a previous cell
# login("hf_xxxxxxxxxxxxxxxxx")

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct"
)

agent = CodeAgent(
    tools=[WebSearchTool()],
    model=model
)

agent.run("What is the distance between Earth and Moon?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the distance between Earth and Moon?                                                                    │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   distance_info = web_search(query="distance between Earth and Moon")
#   print(distance_info)
# ...
